# %% [markdown]
# <a href="https://colab.research.google.com/github/sathakshi03/Sathakshi-FMML_2023/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-07 10:27:11--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   140MB/s    in 0.5s
#
# 2024-03-07 10:27:12 (140 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 23261   1009.1013v1  Dermoscopy is a non-invasive skin imaging tech...    cs
# 32003   0910.0349v1  In Data Mining, the usefulness of association ...    cs
# 15666  1601.01530v4  Recurrent Neural Network (RNN) and one of its ...    cs
# 2363    1301.6684v1  In this paper, we empirically evaluate algorit...    cs
# 9972   1511.08967v1  Reinforcement learning (RL) is a general and w...    cs
# ...             ...                                                ...   ...
# 34151   1405.6678v1  In this article we show that hybrid type-logic...    cs
# 13629   1403.1073v1  This paper describes a new model for an artifi...    cs
# 22872  1709.08135v1  As renewable distributed energy resources (DER...  stat
# 25674  1511.02126v1  Deep ConvNets have shown its good performance ...    cs
# 713    1612.09506v2  With rapid development of the Internet, web co...  stat
#
#                                                    title  year  \
# 23261  Automatic Detection of Blue-White Veil and Rel...  2010
# 32003  Post-Processing of Discovered Association Rule...  2009
# 15666  Leveraging Sentence-level Information with Enc...  2016
# 2363              Comparing Bayesian Network Classifiers  2013
# 9972   Robotic Search & Rescue via Online Multi-task ...  2015
# ...                                                  ...   ...
# 34151  Hybrid Type-Logical Grammars, First-Order Line...  2014
# 13629    Artificial Neuron Modelling Based on Wave Shape  2014
# 22872  Weather Forecasting Error in Solar Energy Fore...  2017
# 25674  Pooling the Convolutional Layers in Deep ConvN...  2015
# 713    Smart Content Recognition from Images Using a ...  2016
#
#                                                 keywords
# 23261  [dermoscopy, technique, visualization, pigment...
# 32003  [usefulness, association, delivered, discovere...
# 15666  [recurrent, architectures, explicitly, depende...
# 2363   [empirically, algorithms, classifiers, augment...
# 9972   [reinforcement, particular, versatile, prohibi...
# ...                                                  ...
# 34151  [embedding, important, consequences, clarifyin...
# 13629  [describes, artificial, processing, different,...
# 22872  [renewable, distributed, resources, penetrate,...
# 25674  [performance, classification, representation, ...
# 713    [development, available, workplace, neverthele...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 23261    [dermoscopy, technique, visualization, pigment...
# 32003    [usefulness, association, delivered, discovere...
# 15666    [recurrent, architectures, explicitly, depende...
# 2363     [empirically, algorithms, classifiers, augment...
# 9972     [reinforcement, particular, versatile, prohibi...
#                                ...
# 6674     [maximizing, operating, characteristic, imbala...
# 1322     [convolutional, performance, classification, r...
# 3889     [statistics, newtonian, gravitational, potenti...
# 10354    [applications, multivariate, previously, unrec...
# 10586    [clustering, algorithm, chaudhuri, variations,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8794 words.
# Out of those 4541 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="069bc208-0cd0-4f45-a598-2894f061c906" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("069bc208-0cd0-4f45-a598-2894f061c906")) {                    Plotly.newPlot(                        "069bc208-0cd0-4f45-a598-2894f061c906",                        [{"x":["automatic","detection","technique","structures","important","visualization","percentage","classifier","sensitivity","melanocytic","specificity","recognition","contextual","diagnosis","dermoscopy","classification","examination","descriptor","strengthen","represent","usefulness","analyzing","processing","delivered","framework","iterative","knowledge","successfully","suggested","interactive","furthermore","integration","ontologies","association","discovered","essential","understanding","architectures","dependencies","component","explicitly","recurrent","enhancement","combining","leveraging","incorporate","information","considering","experiments","empirically","classifiers","independence","algorithm","competitive","algorithms","computational","effective","demonstrate","communities","comparing","formalisms","experimental","attention","augmented","collectively","relatively","conditional","efficiently","evaluated","consecutive","reinforcement","empirical","conditions","particular","accelerate","environment","different","implementations","implemented","prohibitively","expensive","efficient","performance","versatile","functions","regression","dependence","parameters","exponential","characterized","exponents","corresponding","confidence","complexity","distributions","entropies","dimensional","efficiency","clustering","outperforms","outdegree","advantages","extensive","fundamental","applications","implementation","agglomerative","characterizes","intersection","expansions","structure","comparison","represented","footprints","comprehensive","adjustment","relationship","orientation","expansion","connections","experiment","topological","assistant","validation","operations","selection","introducing","simplified","constrains","contribution","directions","constructed","connection","performed","undirected","recommendations","embeddings","researchers","comparative","primarily","architectural","representation","seemingly","systematically","vocabulary","comprehension","eigenvalue","approaches","consequences","uncorrelated","individual","rademacher","convergence","regarding","similarities","segmentation","clustered","visualizing","instructional","illustration","segmenting","according","interface","topologically","semantically","condensed","dissimilarity","guarantees","similarity","probability","potential","stochastic","probabilistic","interpret","coordinate","principled","geometric","riemannian","invariant","synthetic","generation","prevalent","adversarial","complicate","supervised","specifically","determine","procedure","introduced","generates","generative","simultaneously","convolutional","horizontal","asynchronous","harnessed","parallelism","guaranteeing","distributed","performing"],"y":[196,335,243,150,357,21,8,155,31,2,11,391,52,42,2,490,4,28,6,134,26,64,275,5,524,91,343,90,28,39,156,49,18,29,26,66,176,127,59,97,68,131,35,100,54,53,671,73,586,79,104,33,840,119,610,286,250,539,30,77,12,395,157,44,9,77,101,170,144,20,120,131,129,269,18,97,685,35,112,11,46,395,922,13,208,113,24,246,49,27,0,145,49,230,109,0,195,151,135,268,2,77,177,88,431,123,4,14,12,5,376,112,96,1,58,11,73,29,16,53,75,20,7,46,55,157,46,15,6,68,50,64,46,128,8,17,74,62,35,20,9,359,7,29,30,14,5,448,11,1,107,4,121,39,33,201,10,8,4,4,16,93,32,1,28,1,9,63,134,174,154,136,171,22,20,20,69,12,57,139,136,7,95,1,172,161,67,100,142,44,105,108,390,7,14,1,13,3,98,79],"type":"bar"},{"x":["automatic","detection","technique","structures" ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4541,), (4541, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8025

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dependent</span> <span style=''>Path</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Normalization</span> <span style=''>in</span> <span style=''>Neural</span> <span style=''>Networks</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>unified</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>neural</span> <span style=''>net</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>normalization</span> <span style='background-color:rgba(255, 0, 0, 0.35245901639344257);'>regularization</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>which</span> <span style=''>includes</span> <span style=''>Path</span> <span style=''>SGD</span> <span style=''>and</span> <span style=''>Batch</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Normalization</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>interpolates</span> <span style=''>between</span> <span style=''>them</span> <span style=''>across</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>different</span> <span style='background-color:rgba(255, 0, 0, 0.32758620689655166);'>dimensions</span> <span style=''>Through</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3618677042801557);'>investigate</span> <span style=''>issue</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714285);'>invariance</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.34246575342465746);'>dependence</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>connection</span> <span style=''>with</span> <span style=''>natural</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>gradients</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Dependence</span> <span style=''>Measure</span> <span style=''>for</span> <span style=''>non</span> <span style=''>additive</span> <span style=''>model</span> <br/><br/><span style=''>We</span> <span style=''>proposed</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependency</span> <span style=''>measure</span> <span style=''>called</span> <span style=''>Copula</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Dependency</span> <span style=''>Coefficient(CDC)</span> <span style=''>for</span> <span style=''>two</span> <span style=''>sets</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>based</span> <span style=''>on</span> <span style=''>copula</span> <span style=''>It</span> <span style=''>is</span> <span style=''>robust</span> <span style=''>to</span> <span style=''>outliers</span> <span style=''>easy</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implement</span> <span style=''>powerful</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>appropriate</span> <span style=''>to</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>These</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>in</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Experimental</span> <span style=''>results</span> <span style=''>show</span> <span style=''>that</span> <span style=''>CDC</span> <span style=''>can</span> <span style=''>detect</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependence</span> <span style=''>between</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>in</span> <span style=''>both</span> <span style=''>additive</span> <span style=''>and</span> <span style=''>non</span> <span style=''>additive</span> <span style=''>models</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Using</span> <span style=''>Tree</span> <span style='background-color:rgba(255, 0, 0, 0.4285714285714286);'>Decomposable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Structures</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Approximate</span> <span style=''>Belief</span> <span style=''>Networks</span> <br/><br/><span style=''>Tree</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structures</span> <span style=''>have</span> <span style=''>been</span> <span style=''>shown</span> <span style=''>to</span> <span style=''>provide</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.39999999999999997);'>propagating</span> <span style=''>beliefs</span> <span style=''>Pearl1986</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>studies</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>finding</span> <span style=''>an</span> <span style=''>optimal</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333333);'>approximating</span> <span style=''>tree</span> <span style=''>The</span> <span style=''>star</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style=''>scheme</span> <span style=''>for</span> <span style=''>sets</span> <span style=''>of</span> <span style=''>three</span> <span style=''>binary</span> <span style='background-color:rgba(255, 0, 0, 0.32227488151658756);'>variables</span> <span style=''>Lazarsfeld1966</span> <span style=''>Pearl1986</span> <span style=''>is</span> <span style=''>shown</span> <span style=''>to</span> <span style=''>enhance</span> <span style=''>the</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style='background-color:rgba(255, 0, 0, 0.3806818181818181);'>distributions</span> <span style=''>that</span> <span style=''>can</span> <span style=''>support</span> <span style=''>tree</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structures</span> <span style=''>such</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structures</span> <span style=''>are</span> <span style=''>called</span> <span style=''>tree</span> <span style='background-color:rgba(255, 0, 0, 0.4285714285714286);'>decomposable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structures</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>logarithm</span> <span style=''>scoring</span> <span style=''>rule</span> <span style=''>is</span> <span style=''>found</span> <span style=''>to</span> <span style=''>be</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>appropriate</span> <span style='background-color:rgba(255, 0, 0, 0.3454545454545454);'>optimality</span> <span style='background-color:rgba(255, 0, 0, 0.37499999999999994);'>criterion</span> <span style=''>to</span> <span style=''>evaluate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>different</span> <span style=''>tree</span> <span style='background-color:rgba(255, 0, 0, 0.4285714285714286);'>decomposable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structures</span> <span style='background-color:rgba(0, 255, 0, 0.47967479674796765);'>Characteristics</span> <span style=''>of</span> <span style=''>such</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structures</span> <span style=''>closest</span> <span style=''>to</span> <span style=''>the</span> <span style=''>actual</span> <span style=''>belief</span> <span style=''>network</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identified</span> <span style=''>using</span> <span style=''>t ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Multi</span> <span style=''>level</span> <span style=''>Residual</span> <span style=''>Networks</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dynamical</span> <span style=''>Systems</span> <span style=''>View</span> <br/><br/><span style=''>Deep</span> <span style=''>residual</span> <span style=''>networks</span> <span style=''>(ResNets)</span> <span style=''>and</span> <span style=''>their</span> <span style=''>variants</span> <span style=''>are</span> <span style=''>widely</span> <span style=''>used</span> <span style=''>in</span> <span style=''>many</span> <span style=''>computer</span> <span style=''>vision</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>and</span> <span style=''>natural</span> <span style=''>language</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>tasks</span> <span style=''>However</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>principles</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>designing</span> <span style=''>and</span> <span style=''>training</span> <span style=''>ResNets</span> <span style=''>are</span> <span style=''>still</span> <span style=''>not</span> <span style=''>fully</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understood</span> <span style=''>Recently</span> <span style=''>several</span> <span style=''>points</span> <span style=''>of</span> <span style=''>view</span> <span style=''>have</span> <span style=''>emerged</span> <span style=''>to</span> <span style=''>try</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpret</span> <span style=''>ResNet</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretically</span> <span style=''>such</span> <span style=''>as</span> <span style=''>unraveled</span> <span style=''>view</span> <span style=''>unrolled</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iterative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dynamical</span> <span style=''>systems</span> <span style=''>view</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>adopt</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dynamical</span> <span style=''>systems</span> <span style=''>point</span> <span style=''>of</span> <span style=''>view</span> <span style=''>and</span> <span style=''>analyze</span> <span style=''>the</span> <span style=''>lesioning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>ResNet</span> <span style=''>both</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretically</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experimentally</span> <span style=''>Based</span> <span style=''>on</span> <span style=''>these</span> <span style=''>analyses</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>additionally</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>accelerating</span> <span style=''>ResNet</span> <span style=''>training</span> <span style=''>We</span> <span style=''>apply</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>method</span> <span style=''>to</span> <span style=''>train</span> <span style=''>ResNets</span> <span style=''>and</span> <span style=''>Wide</span> <span style=''>ResNets</span> <span style=''>for</span> <span style=''>three</s ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	information (0.23853537148951298)
# 	knowledge (0.12193387842161393)
# 	evaluation (0.09953785993601137)
# 	different (0.24351226448631355)
# 	architecture (0.08851759687166726)
# 	segmentation (0.0714539637397796)
# 	experimental (0.14041948098115892)
# 	detection (0.11908993956629932)
# 	convolutional (0.13864201919658728)
# 	recognition (0.1389975115535016)
#
# Some Statistics words are:
# 	stochastic (0.13236034222445897)
# 	statistical (0.14494212380473076)
# 	variables (0.1404126824358329)
# 	estimation (0.17111222949169602)
# 	theoretical (0.1524911927528938)
# 	algorithm (0.3985908404630096)
# 	distribution (0.1872169099144439)
# 	inference (0.18973326623049824)
# 	dimensional (0.18671363865123303)
# 	regression (0.1887267237040765)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="843e9d60-2e2f-4841-8502-264d7c90ff28" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("843e9d60-2e2f-4841-8502-264d7c90ff28")) {                    Plotly.newPlot(                        "843e9d60-2e2f-4841-8502-264d7c90ff28",                        [{"x":["automatic","detection","technique","structures","important","visualization","percentage","classifier","sensitivity","melanocytic","specificity","recognition","contextual","diagnosis","dermoscopy","classification","examination","descriptor","strengthen","represent","usefulness","analyzing","processing","delivered","framework","iterative","knowledge","successfully","suggested","interactive","furthermore","integration","ontologies","association","discovered","essential","understanding","architectures","dependencies","component","explicitly","recurrent","enhancement","combining","leveraging","incorporate","information","considering","experiments","empirically","classifiers","independence","algorithm","competitive","algorithms","computational","effective","demonstrate","communities","comparing","formalisms","experimental","attention","augmented","collectively","relatively","conditional","efficiently","evaluated","consecutive","reinforcement","empirical","conditions","particular","accelerate","environment","different","implementations","implemented","prohibitively","expensive","efficient","performance","versatile","functions","regression","dependence","parameters","exponential","characterized","exponents","corresponding","confidence","complexity","distributions","entropies","dimensional","efficiency","clustering","outperforms","outdegree","advantages","extensive","fundamental","applications","implementation","agglomerative","characterizes","intersection","expansions","structure","comparison","represented","footprints","comprehensive","adjustment","relationship","orientation","expansion","connections","experiment","topological","assistant","validation","operations","selection","introducing","simplified","constrains","contribution","directions","constructed","connection","performed","undirected","recommendations","embeddings","researchers","comparative","primarily","architectural","representation","seemingly","systematically","vocabulary","comprehension","eigenvalue","approaches","consequences","uncorrelated","individual","rademacher","convergence","regarding","similarities","segmentation","clustered","visualizing","instructional","illustration","segmenting","according","interface","topologically","semantically","condensed","dissimilarity","guarantees","similarity","probability","potential","stochastic","probabilistic","interpret","coordinate","principled","geometric","riemannian","invariant","synthetic","generation","prevalent","adversarial","complicate","supervised","specifically","determine","procedure","introduced","generates","generative","simultaneously","convolutional","horizontal","asynchronous","harnessed","parallelism","guaranteeing","distributed","performing","computations","variational","asymptotic","computation","comparably","evaluation","computing","inference","counterpart","optimization","dictionary","components","predictive","competitors","magnitude","intrinsic","interpretability","approximations","approximating","multiscale","exploiting","compressibility","accurately","dimension","concentrated","alternative","subspaces","approximate","approximation","presented","literature","computationally","compression","potentially","substantial","classical","optimizing","gradients","estimates","successive","assumptions","logarithmically","dimensions","theoretical","outperform","trajectory","interpretable","observations","recursive","predictions","dynamical","continuous", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	exponents
# 	entropies
# 	anopheles
# 	substituting
# 	unfeasible
# 	purchases
# 	pseudolikelihood
# 	periodicity
# 	bijective
# 	homoscedastic
# 	elliptical
# 	semiparametric
# 	intercept
# 	volatility
# 	contamination
# 	missingness
# 	supermarket
# 	transitivity
# 	reconstructive
# 	invariances
# Some words which never appear in Statistics papers:
# 	melanocytic
# 	dermoscopy
# 	strengthen
# 	formalisms
# 	outdegree
# 	assistant
# 	instructional
# 	semantically
# 	depicting
# 	subjected
# 	crossover
# 	nonuniform
# 	linearization
# 	reflection
# 	photography
# 	adaptable
# 	infection
# 	specimens
# 	container
# 	disambiguating

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0608184628569685e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.75
